# %% [markdown]
# # Prerequisites
#
# ![image.png](attachment:e264ac76-05fd-4710-b773-8f4e7a39600c.png)
#
# __Statistics :__
# The statistician's perspective has evolved from understanding data. The field of data analysis was originally a field of mathematics based on questions like, how do we better understand the mechanisms that create data? From these questions, probability-based models were used to model the world around us.
#
# ![image.png](attachment:a769bbc5-c3be-4e14-8e36-47e8a3c4ff54.png) ![image.png](attachment:69ef257f-f761-4fc1-8d3c-b767cda1d4f7.png)

# %% [markdown]
# # NLP
# ![image.png](attachment:6a7810db-82f9-4283-b6aa-7f6e395cafb2.png)
# ![image.png](attachment:22cd5c71-181c-4c9a-8e46-106f44a17b43.png)
#
# ## NLP Pipeline
#     1. Text Processing : we need to get the raw text from real world, maybe wikipidea, pdf, doc, audio, books and process them accordingly to extract features out of them.
#     2. Feature Extraction : Text data can not be understood by the computer so we have to convert every character into some form of number which is also called as encoding.
#     3. Modeling : using the extracted data from the above section, depends upon the user requirement choose a ML/DL models and deploy them as a web applications or make it as a package to use in the mobile applications. Use them to predict the unseen data

# %% [markdown]
# ## Capturing Text Data
#
# We can capture the data from the multiple resources as follows
# 1. SQL
# 2. from csv files
# 3. from API's
# 4. Web scrapping
#
#    Now we have to read the captured data using the libraried like pandas and etc.
#
#
#
# Let's see few examples of how to read the data of the few formats

# %% [markdown]
# ## Plain Text

# %%
import os

#Read in a plain text file 

with open(os.path.join('data', 'hieroglyph.txt'), 'r') as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

#Extract text column from a dataframe
df = pd.read_csv(os.path.join('data', 'news.csv'))
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  Fed's Charles Plosser sees high bar for change...
# 1  IFA Magazine  US open: Stocks fall after Fed official hints ...
# 2  IFA Magazine  Fed risks falling 'behind the curve', Charles ...
# 3     Moneynews  Fed's Plosser: Nasty Weather Has Curbed Job Gr...
# 4        NASDAQ  Plosser: Fed May Have to Accelerate Tapering Pace

# %%
# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace
